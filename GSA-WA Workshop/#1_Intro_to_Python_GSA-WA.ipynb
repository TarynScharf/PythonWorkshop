# %% [markdown]
# # Welcome to the CFIGS Python for Geosciences Workshop!
# ## Who are we?
#
# #### Dr. Taryn Scharf (Postdoctoral Researcher - Curtin)
# I am a postdoctoral researcher in the Timescales of Mineral Systems Group, Curtin University (https://research.curtin.edu.au/scieng/research/timescales-of-mineral-systems/). I am involved in developing computational tools that can be integrated with standard geological approaches for mineral analysis. My toolkit includes machine learning (tabular and image data sets), data analytics, and a variety of coding languages. Python is my preferred programming language for scientific data analysis.  I completed my PhD in Applied Geoscience in 2024 at Curtin University. Prior to my PhD, I spent 7 years as a geologist in the mining industry of South Africa. I was initially involved with brown fields exploration, geostatistical resource estimation, and the development of custom scripted solutions for clients. I later gained exposure to mine design, mine scheduling, and requirements analysis for software development.
#
# #### Piero Sampaio (PhD Student - Curtin)
# I did my undergraduate and MSc. in the Federal University of Rio de Janeiro (UFRJ), where I was born and raised. My research is in geochemistry and igneous petrology, more specifically, I use isotopic signatures from ophiolites to try to understand how Earth's mantle composition evolved since the Neoproterozoic. I use Python on a daily basis to process my data, perform advanced data analysis and generate good-looking visuals.
#
# #### Dr. Luc Doucet (Curtin)
# Co-leader of the Earth Dynamics Research Group (http://geodynamics.curtin.edu.au/), I come from Bourg-en-Bresse, a small town in France famously known for its blue-white-red tricoloured (delicious) chickens. After a PhD in St Etienne, France (2012), I was awarded a three years fellowship from the Belgium Fund for Scientific Research to apply the "non-traditional" stable-isotope systematics to study the formation of both oceanic and continental lithosphere. After a two-year academic career break (being a stay-at-home dad), I moved to Curtin University in March 2018 to join the Earth Dynamics Research Group to decipher the present-day and past connections between Earth's mantle, supercontinent and superocean cycles. In 2023, I was awarded an ARC Future Fellowship to study the link between the deep carbon cycle with critical mineral deposits.
#
#
#
# ## Welcome to Python notebooks
# Notebooks are handy ways to run short bits of code (in this case Python) and view results, without having to run a full program or script. This is ideal for practicing short examples or performing small pieces of analytics.

# %% [markdown]
# ## (Very) simple math
# Python has a series of in-built mathematical operators.
# * Addition: 5+2
# * Subtraction: 5-2
# * Multiplication: 5*2
# * Division: 5/2
# * Modulus: 5%2
# * Exponentiation: 5**2

# %%
5**2
# Out:
# 25

# %% [markdown]
# <font color="green"><b>TRY IT YOURSELF:</b> Add 2 to 3, then divide by 2 and return the remainder. HINT: use the modulus operator. </font>

# %%
#type your code here

# %% [markdown]
#  ## Variables
# We use code to automate the processes we must often **repeat**. We want the automated process (e.g. sum two numbers) to work on any inputs we give it.
# To go from 5 + 2 = 7 -> first_number + second_number = answer, we need data "placeholders". These placeholders are called **variables**.

# %%
first_number = 2
second_number = 3 
answer = first_number + second_number
print(answer)

# %% [markdown]
#  <font color="green"><b>TRY IT YOURSELF:</b> Use variables to calculate the average of three values.</font>

# %%
#type your code here

# %% [markdown]
# Variables store your data. There are many **data types**. Data types determine how the data behaves and what we can do to it. Examples of data types are:
# - int: integer numbers
# - float: numbers with decimal values
# - str: text - strings of characters
# - bool: True/False values

# %%
# integer number: you can perform mathematical operations on both integers and floats
my_integer = 42 
print(my_integer +5)

# float (decimal values or fractional numbers). You can round these up or down
my_float = 4.568 
print(round(my_float,1))

# boolean value (condition that be True or False). These are useful for 'if-else' scenarios
my_boolean = True 

print(my_boolean)
# Out:
# 47
# 4.6
# True

# %%
#Strings are alphanumeric. You can manipulate strings extensively in Python
my_string = 'Hello world'
print(f'Original string: {my_string}')

replacement = my_string.replace(' ', '_')
print(f'Replacement: {replacement}')

uppercase = my_string.upper()
print(f'Capitalise: {uppercase}')

substring = my_string[0:5]
print(f'Substring: {substring}') 

multiply = my_string * 3
print(f'Mutiplication: {multiply}')
# Out:
# Original string: Hello world
# Replacement: Hello_world
# Capitalise: HELLO WORLD
# Substring: Hello
# Mutiplication: Hello worldHello worldHello world

# %% [markdown]
# We can also have **composite data types** that store **collections of data**. Python has 4 built-in composite data types:
# - list: mutable (can be changed) object that contains other values

# %%
# a list of numbers. Note the square brackets.
my_list = ["a",23,399.8,False] 

my_list.append(100) #you can add to a list
print(my_list)

print(my_list[3]) # you can get items out of a list using their positional index

my_list[3]='updated' #you can change the values of items in a list
print(my_list)

list_length = len(my_list) #You can query the length of composite data types like lists
print(f'There are {list_length}  items in my_list')
# Out:
# ['a', 23, 399.8, False, 100]
# False
# ['a', 23, 399.8, 'updated', 100]
# There are 5  items in my_list

# %% [markdown]
# - tuple: same, but immutable (cannot be changed)

# %%
#tuples are declared with round brackets
my_tuple = (3,4,5) 
#my_tuple[0]='updated' #tuples cannot be changed after their creation. This won't work. Remove the hash and give it a try.
#my_tuple.append(100) #tuples cannot be changed after their creation. This won't work. Remove the hash and give it a try.
print(my_tuple[1])
# Out:
# 4

# %% [markdown]
# - set: like a list but only contains unique values

# %%
# sets are declared with curly brackets. They contain only UNIQUE values
my_set = {3,4,5} 
print(my_set)

my_set.add(3)
print(my_set)# as 3 already exists in the set, it won't be re-added (you can add multiple elements of the same value, to a list)

my_set.add(6) # we can add 6, because it's not yet in the set
print(my_set)
# Out:
# {3, 4, 5}
# {3, 4, 5}
# {3, 4, 5, 6}

# %% [markdown]
# - dict: key-value pairs

# %%
# a dictionary is made of key: value pairs. Note the curly brackets
drillhole_depths = {
    "ANT001":755.7,
    "ANT002":624.7,
    "ANT003":342.7
} 

drillhole_depths['ANT004']=141
print(f'A drillhole has been added: {drillhole_depths}')

drillhole_id = 'ANT002' #Try changing the key value and rerunning this cell
print(f'Drillhole {drillhole_id} is {drillhole_depths[drillhole_id]}m deep')
print(f'There are {len(drillhole_depths)} recorded drillholes.')

del(drillhole_depths[drillhole_id])
print(f'Drillhole {drillhole_id} has been removed from the dictionary: {drillhole_depths}')
# Out:
# A drillhole has been added: {'ANT001': 755.7, 'ANT002': 624.7, 'ANT003': 342.7, 'ANT004': 141}
# Drillhole ANT002 is 624.7m deep
# There are 4 recorded drillholes.
# Drillhole ANT002 has been removed from the dictionary: {'ANT001': 755.7, 'ANT003': 342.7, 'ANT004': 141}

# %% [markdown]
# ## Functions
# A function is a piece of code that performs an action. Code is often broken up into a series of functions, each performing a specific task.
#
# * In Python we declare functions using the `def` keyword at the beginning of the line.
# * All code that forms part of the function is placed on the next **indentation** level. Each indentation is performed by pressing the tab key.
# * We can press shift + tab to go back to the previous indentation
# * We can use a function when we call it by name.
#
# The classic introduction to any programming language is the hello world function. We will also use the print function, which prints (😲) something to the console.

# %%
def hello_world(): #def define the function hello_world. You can name your function anything you like, but it's best to make it sensible
  print("hello world!") # the function print hello world

hello_world()

# %%
def addition(a,b): 
  c = a + b
  return c 

x = addition(3,4) 
print(x)

# %% [markdown]
#  <font color="green"><b>TRY IT YOURSELF:</b> Turn your previous 3-value-average calculation into a function and print the result</font>

# %%
#Type your code here

# %% [markdown]
# # Loops
# If we want to repeat an action multiple times, sometimes changing only a few factors, we can use a loop to automate that action. Loops come in two flavours:
# `for` and `while` loops.
# ## `For` loop:
# A `for` loop repeats an action for every object in a given group (list, dict, array, etc). The loop will be performed for all code that is within the next **indentation** level. Each indentation is performed by pressing the `tab` key. We can press `shift` + `tab` to go back to the previous indentation

# %%
# different indentation levels
a
  b
    c
      d

# %%
#For loop example:

file_names = ['ANT001_COLLAR.csv', 'Ant001_stratigraphy.csv', 'ANT002_COLLAR.csv', 'ant002_assay.csv', 'aNT003_COLLAR'] 

unique_drillhole_ids = set()

for file in file_names:
    file = file.lower()
    drillhole_id = file.split("_")[0] 
    unique_drillhole_ids.add(drillhole_id) #

print(f'There are {len(unique_drillhole_ids)} drillholes.')
print(f'Unique drillhole IDs: {unique_drillhole_ids}')
# Out:
# There are 3 drillholes.
# Unique drillhole IDs: {'ant002', 'ant001', 'ant003'}

# %% [markdown]
#  <font color="green"><b>TRY IT YOURSELF:</b> Two dictionaries are provided. One is total drillhole depth, the other is rc precollar depth. For each drillhole, calculate the total diamond drill depth by substracting the precollar depth from the total depth.  HINT:  Use dictionary.items() to access the keys from the first dictionary</font>

# %%
drillhole_total_depths = {
    "ANT001":755.7,
    "ANT002":624.7,
    "ANT003":342.7,
    "ANT004": 141
} 

drillhole_rc_precollar_depth = {
    "ANT001":104.7,
    "ANT002":117,
    "ANT003":104.7,
    "ANT004": 141
    
}

for dh_id, total_depth in drillhole_total_depths.items():
    #Use the varibales dh_id and total_depth, to get the drillhole ID and total length
    #use the same key (dh_id) to look up the corresponding rc collar depth in the precollar dictionary (inside the for-loop)
    #subtract precollar depth from total depth (inside the for-loop)
    #print the key value and total diamond drill depth calculated (inside the for-loop)
# Out:
#   Cell In[13], line 20
#     #print the key value and total diamond drill depth calculated (inside the for-loop)
#                                                                                        ^
# SyntaxError: incomplete input

# %% [markdown]
# ## `While` loop:
# A `while` loop repeats an action while a condition is `True`

# %%
#While loop example
drill_depth_in_meters = [0, 1.5, 2.2, 3.5, 4.6, 5.8, 6.6, 7.4, 8.6, 9.7, 10.6]

length_drilled = 0
i=0

while length_drilled <7:
    length_drilled = length_drilled + drill_depth_in_meters[i]
    print(f'{length_drilled} meteres drilled after {i+1} iterations') 
    i +=1
# Out:
# 0 meteres drilled after 1 iterations
# 1.5 meteres drilled after 2 iterations
# 3.7 meteres drilled after 3 iterations
# 7.2 meteres drilled after 4 iterations

# %% [markdown]
#  <font color="green"><b>TRY IT YOURSELF:</b> A counter has been provided.  While the counter is less than 10, increment its value by 2 and print out the counter. </font>

# %%
i=0
#Type your code here

# %% [markdown]
# # Conditionals and control
# Conditionals in Python, like in many other programming languages, allow you to make decisions in your code. They help your programs to behave differently based on certain conditions. In Python, you use if, elif (else if), and else statements to create conditionals.
#
# 1. if Statements:
# The if statement is used to execute a block of code if a condition is true.
#
# 2. elif Statements:
# elif is short for "else if". It allows you to check multiple conditions. If the first if condition is false, it checks the next elif condition, and so on.
#
# 3. else Statements:
# The else statement is used to execute a block of code if none of the conditions in the if and elif statements are true.
#
# 4. Nesting Conditionals:
# You can also nest conditionals inside each other to handle more complex situations.

# %%
# if statement:
num = 15
if num % 2 == 0:
    print("Even")

# %%
# else statement
num = 15
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
# elif statement:
average_grams_per_tonne = 7.85
if average_grams_per_tonne >= 10:
    print("High grade")
elif average_grams_per_tonne >= 5 and average_grams_per_tonne<10:
    print("Medium grade")
elif average_grams_per_tonne>=1 and average_grams_per_tonne < 5:
    print("Low grade")
else:
    print('Subeconomic')
# Out:
# Medium grade

# %% [markdown]
# ## We can mix loops and conditionals to make more complex actions
# Have you ever inhereted a messy  folder of project data? Let's standardise file names in a folder.

# %%
import os

folder_path = 'Antrim_data'

#get a list of everything in the folder
folder_contents = os.listdir(folder_path)

#loop through every item in the list
for item in folder_contents:

    #if the item is not a file (i.e. its a folder), continue looping (ignore the item)
    if 'xls' not in  item:
        continue

    #create new file names
    item_name = item.lower()
    if "majors" in item_name:
        new_item_name = "antrim_assay_major_elements.xls"
    elif "traces" in item_name:
        new_item_name = "antrim_assay_trace_elements.xls"
    elif "collar" in item_name:
        new_item_name = "antrim_collars.xls"
    elif "geology" in item_name:
        new_item_name = "antrim_stratigraphy.xls"
    else:
        print("No borehole data found")

    old_path = os.path.join(folder_path, item)
    new_path = os.path.join(folder_path, new_item_name)
    if not os.path.exists(new_path):
        os.rename(old_path, new_path)
        print(f"Renamed: {item} to {new_item_name}")

# %% [markdown]
#  <font color="green"><b>TRY IT YOURSELF:</b> Let's loop through the contents of the Antrim folder and separate Excel and image files into their own folders. <br>
#  HINTS:
#  * We will use os.path.exists(path) to test whether a folder already exists (so we don't overwrite it)
#  * We will use os.makedirs(path) to create a new folder if it doesn't exist. \n
#  * We will use os.path.join(folder_path, file_name) to get the full path of files
#  * We will use os.path.replace(old_file_path, new_file_path) to move files between folders.

# %%
import os

folder_path = 'Antrim_data'

#create two new folders, one for excel and one for image files
excel_data_folder = os.path.join(folder_path, 'drillhole_data')
image_data_folder = os.path.join(folder_path, 'drillhole_images')

if not os.path.exists(excel_data_folder):
        os.makedirs(excel_data_folder)

if not os.path.exists(image_data_folder):
        os.makedirs(image_data_folder)

#get a list of everything in the folder
folder_contents = os.listdir(folder_path)

#loop through every item in the list
for item in folder_contents:

    #if the item is not a file (i.e. its a folder), continue looping (ignore the item)
    if not os.path.isfile(os.path.join(folder_path,item)):
        if item == 'New folder':
            os.rmdir(os.path.join(folder_path,item))
        else:
            continue
    
    file_extension = os.path.splitext(item)[1]

    if file_extension == '.xls':
        old_file_path = os.path.join(folder_path, item)
        new_file_path = os.path.join(excel_data_folder, item)
        os.replace(old_file_path, new_file_path)
        
    if file_extension == '.jpg':
        old_file_path = os.path.join(folder_path, item)
        new_file_path = os.path.join(image_data_folder, item)
        os.replace(old_file_path, new_file_path)

# %%
#1 - import the os package, as we did in the previous example

#2 - Create a variable that holds the path of the Antrim_data folder, as we did in the previous example

#3 - create a variable that holds the new folder path for excel files. This folder will live INSIDE the Antrim_data folder. Here's how to do it:
excel_data_folder = os.path.join(folder_path, 'drillhole_data')

#4 - Repeat step 3 to create a new folder path for image data

#5 - Get a list of everything in the folder, as we did in the previous example.

#6 - loop through every item in the list. If an item is a folder do the  following: 
# 1) test if it's called "New Folder". If it is, delete it. 2)Otherwise, skip it as we did in the previous example. Here's how to do it:
if not os.path.isfile(os.path.join(folder_path,item)):
        if item == 'New folder':
            os.rmdir(os.path.join(folder_path,item))
        else:
            continue
#7 - If the item is a file (i.e. not a folder), get the file extension using as follows:
file_extension = os.path.splitext(file_path)

#8 - Use an if-statement to test whether the file_extension is 'xls'. You can test equivalent like this: 
if file_extension == '.xls:"

#9 - if it is an excel file, define the new file path  for this file (remember, it will be moved to a new folder).
#You can using os.path.join (path, filename) to create a new path for the file like this:
old_file_path = os.join.path(folder_path, item)
new_file_path = os.join.path(excel_data_folder, item)

#10 - Move the file into its new folder using os.replace(old_file_path, new_file_path)
os.replace(old_file_path, new_file_path)

#Repeat steps 8-10 for the case of image files (.png file extension).

# %% [markdown]
# # The true power of Python: Libraries (or modules)
# Python goes way beyond by using different libraries. Libraries extend the functionality of Python. There are some built-in Python libraries (e.g. math), but there are heaps of user-created libraries. Whenever you want to do something on Python, chances are that someone has already created a library to make your life easier. First, we must import the desired library using the `import` statement. Generally, imports are in the first part of the code.
#
# Examples of built-in libraries are `math`, `os`, `time`,`stats`, etc
#
# The `math` library, for example, has many useful mathematical functions already implemented. Once we import the library we can access the functions in the library by using the `.` after the name of the library:
# `math.cos()` would give you the cosine function. Certain libraries also have attributes which can be accessed in the same way, such as `math.pi`. Note that this is not a function, so it does not need the parentheses after it.
#
# We have already used the `os` library to help us organise the drillhole datafiles.

# %%
import math
c = math.cos(math.pi) # we use the dot to access the cosine function
print(c)
# Out:
# -1.0

# %% [markdown]
# We can also import only certain functions of a library. In that case we do not need to use the `math.cos()` anymore, we can call the function directly.

# %%
from math import cos
c = cos(math.pi)
print(c)
# Out:
# -1.0

# %% [markdown]
# Finally, we can also import a library with an alias that will be used throughout the code. For the `math` library that doesn't really matter but for libraries with longer names (classic example would be `matplotlib.pyplot`) it is useful.

# %% [markdown]
# ## External libraries
#
# These libraries, created and shared by the global Python community, cater to diverse needs such as data analysis, web development, machine learning, and more. For instance, the Pandas library simplifies data manipulation and analysis through its powerful data structures, the Matplotlib library enables high-quality data visualization and numpy for numerical calculations. These libraries expand Python's capabilities dramatically, allowing developers to leverage pre-built solutions and focus more on problem-solving rather than reinventing the wheel.
#
# In this workshop, we`ll be using mostly external libraries and applying them to geology related problems. The main libraries we'll use are:
# - [numpy](https://numpy.org/)
# - [scipy](https://scipy.org/)
# - [matplotlib](https://matplotlib.org/)
# - [pandas](https://pandas.pydata.org/)
# - [geopandas](https://geopandas.org/en/stable/)
# - [seaborn](https://seaborn.pydata.org/)
# - [pyrolite](https://pyrolite.readthedocs.io/en/main/) (developed by Morgan Williams of CSIRO)
# - [PyGMT](https://www.pygmt.org/latest/index.html) (maintained by a group of geophysicists in various places)
#
# For example the `numpy` library extends (a lot) the functionality of the `math` library. One use case is that `math` operates on single objects, whereas `numpy` operates on arrays (a type of group of objects) directly, which saves us from using loops all the time. This is great, because loops are very inefficient in terms of speed. It might not be vital for short tasks, but it scales very quickly.
#
# ## Numpy
# This is your go-to for almost all numerical applications in Python. Fast, highly optimized library for working with arrays of numbers.

# %%
# with math
import math

gp1 = range(0,20,1) # built-in function to define a range of numbers: range(start number, number to stop before, increment)
results = [] # create list to store results
for i in gp1:
  results.append(math.sqrt(i))
print(results)

# math only takes real numbers as input

# %%
# with numpy
import numpy as np # common alias for numpy

results = np.sqrt(gp1) # we can operate directly on the range object
results # the object is returned as an array data type, which is the type on which numpy operates

# %%
# numpy also has its own version of the range function which automatically generates an array
arr = np.arange(0,100,5) # very similar functionality to Python's built-in range function. np.arange(start, stop, step)
arr2 = np.linspace(0,100,20) # (start, stop, count) this creates an array with evenly spaced values that range from start to stop. You provide the count/number of numbers to create and the step size is inferred.

print(f'array 1: {arr}')
print(f'array 2: {arr2}')

# %%
# We can access items in the array by using indexes (positional number in the list).
# Keep in mind that Python starts counting from 0.
arr = np.arange(0,100,5) # start, stop, step
print(arr[0]) # returns the first item in the array

# %%
print(arr2[-1]) # -1 is a shortcut for last item in the array. We can count backwards from -1

# %%
# we can also index with slices
# [start:stop] where stop is not inclusive
print(arr[0:5]) # first five items of the array

# %%
# And finally this works for multidimensional arrays as well
# The dimensions are separated by commas, so notation is similar to that of a matrix

# arrays also don't need to be 1d, they can have multiple dimensions. For example, here we reshape our 20-number arrange into a 2D matrix that has 2 rows and 10 columns:
arr_2d = arr.reshape(2,10)
print(arr_2d)
print(f'slice through array 2d:\n {arr_2d[:,4:6]}') # returns the item in the fifth column of the first line (remember we count from 0)

# %% [markdown]
# ## Pandas

# %% [markdown]
# Pandas is your go to for handling data tables.

# %%
import pandas as pd

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\283284g\appdata\local\programs\python\python312\lib\site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: C:\Users\283284G\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
#Let's major element data, skipping unwanted rows

#But first, a bit of house-keeping to help us view all the table columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# 27  3.38  0.17   0.2  52.64  1.49  1.55   99.9
# 28  2.77  0.18  0.04  53.39  1.52  0.69  100.3

# %%
#There are some below-detection values ('<') in the SO3 column. Let's set those to 0.5*detection limit

#Let's get all the columns in the dataframe
columns = majors_df.columns
print(f'All dataframe columns: {columns}')

#We'll use slicing to get the major element columns that we want
major_elements = columns[3:-1]
print(f'\nMajor element columns: {major_elements}\n')

#There are values below detection limit in the SO3 column, rows 15-17.
#Let's assign a value of 0.005
majors_df[major_elements] = majors_df[major_elements].replace('<', 0.005)
majors_df
# Out:
# All dataframe columns: Index(['sampleid', 'Location', 'Interval', 'Al2O3', 'CaO', 'Fe2O3', 'K2O',
#        'MgO', 'MnO', 'Na2O', 'P2O5', 'SO3', 'SiO2', 'TiO2', 'LOI', 'Total'],
#       dtype='object')
#
# Major element columns: Index(['Al2O3', 'CaO', 'Fe2O3', 'K2O', 'MgO', 'MnO', 'Na2O', 'P2O5', 'SO3',
#        'SiO2', 'TiO2', 'LOI'],
#       dtype='object')
#     sampleid Location       Interval  Al2O3   CaO  Fe2O3   K2O   MgO   MnO  \
# 0     414001   ANT001    104.3-104.5  14.99  7.88  10.42  1.72  5.10  0.19
# 1     414002   ANT001    149.5-149.7  15.46  8.17   9.32  1.70  5.04  0.13
# 2     414003   ANT001  198.65-198.85  14.23  7.13   9.57  1.95  4.98  0.15
# 3     414004   ANT001  250.25-250.45  15.67  9.02   9.25  1.54  5.01  0.14
# 4     414005   ANT001   308.4-308.65  14.23  6.92  11.22  2.27  5.08  0.18
# 5     414006   ANT001    348.7-348.9  13.40  6.04  12.40  1.49  3.95  0.17
# 6     414007   ANT001  395.05-395.25  14.22  6.96  11.23  1.56  5.55  0.16
# 7     414008   ANT001    415.8-416.0  12.73  7.50  13.09  1.65  4.04  0.18
# 8     414009   ANT001    450.2-450.4  13.46  7.29  13.25  1.77  4.41  0.20
# 9     414010   ANT001    465.6-465.8  13.31  7.26  13.63  1.78  4.26  0.20
# 10    414011   ANT001    432.7-432.9  13.27  6.76  13.68  1.95  4.04  0.20
# 11    414017   ANT002  117.95-118.15  14.72  6.29  10.85  1.87  5.70  0.16
# 12    414018   ANT002    157.8-158.0  15.51  7.61   9.26  1.84  4.35  0.13
# 13    414019   ANT002    179.4-179.6  14.31  7.77   9.34  1.85  5.05  0.15
# 14    414020   ANT002  201.75-201.95  14.73  7.43   9.05  1.95  4.63  0.16
# 15    414021   ANT002    224.8-225.0  15.12  8.35   8.61  1.57  6.02  0.14
# 16    414022   ANT002    247.5-247.7  15.57  9.71  10.47  1.14  6.11  0.15
# 17    414023   ANT002    274.0-274.2  15.49  9.71  10.43  1.14  6.12  0.15
# 18    414024   ANT002    302.4-302.6  15.03  9.41  11.03  1.29  5.68  0.17
# 19    414025   ANT002    327.4-327.6  14.17  6.83  11.33  1.81  5.32  0.20
# 20    414026   ANT002    334.0-334.2  14.23  4.88  11.64  3.23  4.95  0.25
# 21    414027   ANT002    349.8-350.0  14.01  4.71  10.98  1.70  6.69  0.27
majors_df['To'] = majors_df['Interval'].str.split('-').str[1]
majors_df.drop('Interval',axis = 1, inplace = True)
majors_df.head()
#merged_assay_df.to_csv('Antrim_data/antrim_assay_major_and_trace_elements.csv')
# Out:
#    sampleid Location  Al2O3   CaO  Fe2O3   K2O   MgO   MnO  Na2O  P2O5   SO3  \
# 0    414001   ANT001  14.99  7.88  10.42  1.72  5.10  0.19  3.33  0.15  0.06
# 1    414002   ANT001  15.46  8.17   9.32  1.70  5.04  0.13  3.03  0.14  0.14
# 2    414003   ANT001  14.23  7.13   9.57  1.95  4.98  0.15  3.46  0.16  0.01
# 3    414004   ANT001  15.67  9.02   9.25  1.54  5.01  0.14  2.48  0.14  0.02
# 4    414005   ANT001  14.23  6.92  11.22  2.27  5.08  0.18  4.33  0.16  0.05
#
#     SiO2  TiO2   LOI  Total    From      To
# 0  52.71  1.28  1.65   99.4   104.3   104.5
# 1  54.90  0.98  1.24  100.2   149.5   149.7
# 2  55.66  1.07  1.37   99.8  198.65  198.85
# 3  54.51  1.02  0.85   99.7  250.25  250.45
# 4  52.66  1.35  1.50   99.9   308.4  308.65

# %% [markdown]
# So far we have:
# - read the data from excel
# - assigned NAN values where numbers were missing
# - removed duplicate values
# - calculated new From and To columns
# - remove unwanted columns
#
# We would need to repeat all this code for the table containing trace elements. Instead, let's create a function that will do all this data processing on each assay file we give it.

# %%
def process_assay_data(file_path, header_row, rows_to_skip):
    dataframe = pd.read_excel(file_path, header=header_row, skiprows=rows_to_skip)

    assay_columns = dataframe.columns[3:]
    dataframe[assay_columns] = dataframe[assay_columns].replace('<', 0.005)
    
    for column in assay_columns:
        dataframe[column] = pd.to_numeric(dataframe[column], errors='coerce')

    dataframe.drop_duplicates(inplace= True, ignore_index = True)

    dataframe['From'] = dataframe['Interval'].str.split('-').str[0]
    dataframe['To'] = dataframe['Interval'].str.split('-').str[1]
    dataframe.drop('Interval',axis = 1, inplace = True)

    dataframe.columns.values[0] = 'sampleid'

    return dataframe

major_elements = process_assay_data('Antrim_data/drillhole_data/antrim_assay_major_elements.xls', 1, [2, 3, 4, 5])
trace_elements = process_assay_data('Antrim_data/drillhole_data/antrim_assay_trace_elements.xls', 0, [1,2, 3, 4, 5])
# Out:
# C:\Users\283284G\AppData\Local\Temp\ipykernel_13272\2153274947.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataframe[assay_columns] = dataframe[assay_columns].replace('<', 0.005)

# %%
major_elements.head()
# Out:
#    sampleid Location  Al2O3   CaO  Fe2O3   K2O   MgO   MnO  Na2O  P2O5   SO3  \
# 0    414001   ANT001  14.99  7.88  10.42  1.72  5.10  0.19  3.33  0.15  0.06
# 1    414002   ANT001  15.46  8.17   9.32  1.70  5.04  0.13  3.03  0.14  0.14
# 2    414003   ANT001  14.23  7.13   9.57  1.95  4.98  0.15  3.46  0.16  0.01
# 3    414004   ANT001  15.67  9.02   9.25  1.54  5.01  0.14  2.48  0.14  0.02
# 4    414005   ANT001  14.23  6.92  11.22  2.27  5.08  0.18  4.33  0.16  0.05
#
#     SiO2  TiO2   LOI  Total    From      To
# 0  52.71  1.28  1.65   99.4   104.3   104.5
# 1  54.90  0.98  1.24  100.2   149.5   149.7
# 2  55.66  1.07  1.37   99.8  198.65  198.85
# 3  54.51  1.02  0.85   99.7  250.25  250.45
# 4  52.66  1.35  1.50   99.9   308.4  308.65

# %%
trace_elements.head()
# Out:
#   sampleid Location     Ba     Ce    Co     Cr    Cu    Dy    Er    Eu    Gd  \
# 0   414001   ANT001  311.4  44.11  37.0   85.0  49.0  6.03  3.33  1.38  5.18
# 1   414002   ANT001  303.6  46.34  30.0  134.0  38.0  5.60  3.16  1.26  4.98
# 2   414003   ANT001  340.0  53.52  32.0  113.0  71.0  6.52  3.67  1.32  5.96
# 3   414004   ANT001  303.1  46.22  32.0  125.0  57.0  5.78  3.11  1.27  5.04
# 4   414005   ANT001  359.8  46.32  37.0   69.0  41.0  6.68  3.67  1.53  5.53
#
#      Hf    Ho     La     Lu    Nb     Nd    Ni     Pr     Rb    Sm     Sr  \
# 0  4.45  1.17  20.50  0.452  9.45  20.85  50.0  5.272  65.45  4.82  160.0
# 1  4.05  1.08  22.02  0.435  8.77  20.94  70.0  5.327  77.02  4.61  159.0
# 2  4.74  1.26  25.51  0.482  9.87  24.45  49.0  6.225  87.09  5.46  146.0
# 3  4.17  1.07  21.87  0.433  8.73  21.43  47.0  5.450  69.49  4.77  161.0
# 4  4.76  1.25  21.95  0.514  9.16  22.47  43.0  5.549  97.61  5.15  147.0
#
#      Ta     Tb     Th    Tm     U      V      Y    Yb     Zn     Zr    From  \
# 0  0.92  0.917   7.85  0.50  1.23  262.0  29.10  3.18   87.0  160.9   104.3
# 1  0.80  0.830   9.59  0.45  1.70  187.0  27.75  2.91   97.0  153.0   149.5
# 2  0.90  1.015  11.20  0.53  2.07  200.0  30.40  3.34  105.0  169.7  198.65
# 3  0.73  0.877   9.24  0.47  1.56  188.0  27.90  2.97   87.0  151.5  250.25
# 4  0.68  0.969   8.15  0.54  1.35  287.0  31.30  3.48   74.0  173.7   308.4
#
#        To
# 0   104.5
# 1   149.7
# 2  198.85
# 3  250.45
# 4  308.65

# %% [markdown]
# There are checks (duplicates), standards and blanks in our trace element data. <br> Lets remove them from the assay table and set them aside for later.

# %%
nan_rows = trace_elements[trace_elements.isnull().all(axis=1)]
nan_row_indices = nan_rows.index
trace_elements_without_blanks = trace_elements.iloc[:nan_row_indices[0]]
checks_standards_blanks = trace_elements.iloc[nan_row_indices[0]:]

# %%
trace_elements_without_blanks.head()
# Out:
#   sampleid Location     Ba     Ce    Co     Cr    Cu    Dy    Er    Eu    Gd  \
# 0   414001   ANT001  311.4  44.11  37.0   85.0  49.0  6.03  3.33  1.38  5.18
# 1   414002   ANT001  303.6  46.34  30.0  134.0  38.0  5.60  3.16  1.26  4.98
# 2   414003   ANT001  340.0  53.52  32.0  113.0  71.0  6.52  3.67  1.32  5.96
# 3   414004   ANT001  303.1  46.22  32.0  125.0  57.0  5.78  3.11  1.27  5.04
# 4   414005   ANT001  359.8  46.32  37.0   69.0  41.0  6.68  3.67  1.53  5.53
#
#      Hf    Ho     La     Lu    Nb     Nd    Ni     Pr     Rb    Sm     Sr  \
# 0  4.45  1.17  20.50  0.452  9.45  20.85  50.0  5.272  65.45  4.82  160.0
# 1  4.05  1.08  22.02  0.435  8.77  20.94  70.0  5.327  77.02  4.61  159.0
# 2  4.74  1.26  25.51  0.482  9.87  24.45  49.0  6.225  87.09  5.46  146.0
# 3  4.17  1.07  21.87  0.433  8.73  21.43  47.0  5.450  69.49  4.77  161.0
# 4  4.76  1.25  21.95  0.514  9.16  22.47  43.0  5.549  97.61  5.15  147.0
#
#      Ta     Tb     Th    Tm     U      V      Y    Yb     Zn     Zr    From  \
# 0  0.92  0.917   7.85  0.50  1.23  262.0  29.10  3.18   87.0  160.9   104.3
# 1  0.80  0.830   9.59  0.45  1.70  187.0  27.75  2.91   97.0  153.0   149.5
# 2  0.90  1.015  11.20  0.53  2.07  200.0  30.40  3.34  105.0  169.7  198.65
# 3  0.73  0.877   9.24  0.47  1.56  188.0  27.90  2.97   87.0  151.5  250.25
# 4  0.68  0.969   8.15  0.54  1.35  287.0  31.30  3.48   74.0  173.7   308.4
#
#        To
# 0   104.5
# 1   149.7
# 2  198.85
# 3  250.45
# 4  308.65

# %%
checks_standards_blanks.head()
# Out:
#      sampleid Location     Ba     Ce    Co    Cr    Cu    Dy    Er    Eu  \
# 29        NaN      NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 30     CHECKS      NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 31     414001      NaN  313.3  44.07  37.0  81.0  47.0  5.96  3.31  1.40
# 32     414032      NaN  207.6  46.31  41.0  24.0  65.0  6.58  3.75  1.41
# 33  STANDARDS      NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#       Gd    Hf    Ho     La     Lu    Nb     Nd    Ni     Pr     Rb    Sm  \
# 29   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN    NaN    NaN   NaN
# 30   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN    NaN    NaN   NaN
# 31  5.24  4.51  1.15  20.42  0.448  8.51  20.95  51.0  5.265  65.83  4.85
# 32  5.78  4.38  1.28  21.34  0.505  9.46  22.42  21.0  5.491  36.45  5.30
# 33   NaN   NaN   NaN    NaN    NaN   NaN    NaN   NaN    NaN    NaN   NaN
#
#        Sr    Ta     Tb    Th    Tm     U      V      Y    Yb    Zn     Zr  \
# 29    NaN   NaN    NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 30    NaN   NaN    NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 31  166.0  0.60  0.879  7.98  0.49  1.29  263.0  29.43  3.09  86.0  161.4
# 32  144.0  0.69  1.000  8.67  0.55  1.40  301.0  33.89  3.49  92.0  160.5
# 33    NaN   NaN    NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN    NaN
#
#    From   To
# 29  NaN  NaN
# 30  NaN  NaN
# 31  NaN  NaN
# 32  NaN  NaN
# 33  NaN  NaN

# %%
#Let's merge the major and trace element assay into one file, and save the file
# 15  2.77   70.0  143.4
# 16  2.89   72.0  143.2
# 17  2.79   87.0  134.0
# 18  2.98   79.0  141.8
# 19  3.37   76.0  169.4
# 20  3.09   81.0  145.0
# 21  2.48  126.0  106.1
# 22  2.71   90.0  119.2
# 23  2.59   83.0  110.2
# 24  3.32  271.0  141.8
# 25  3.23  111.0  140.3
# 26  3.54   91.0  160.9
# 27  3.67  107.0  164.8
# 28  3.67   88.0  168.1

# %%
#Let's save our new assay table to a csv file, which can be imported into any software.
merged_assay_df.to_csv('Antrim_data/drillhole_data/Antrim_assay_data.csv')

# %%
#Lets do some very basic comparisons of the values in our boreholes
average_per_drillhole = merged_assay_df.groupby('Location').mean(numeric_only=True).round(2)
average_per_drillhole
# Out:
#           Al2O3   CaO  Fe2O3   K2O   MgO   MnO  Na2O  P2O5   SO3   SiO2  TiO2  \
# Location
# ANT001    14.09  7.36  11.55  1.76  4.68  0.17  3.84  0.15  0.51  53.42  1.30
# ANT002    14.42  7.22  11.17  1.76  5.40  0.18  3.55  0.14  0.20  53.34  1.21
#
#            LOI  Total      Ba     Ce     Co     Cr     Cu    Dy    Er    Eu  \
# Location
# ANT001    1.55  99.90  292.73  48.22  37.36  63.09  47.00  6.43  3.57  1.41
# ANT002    1.53  99.95  259.67  44.80  36.61  77.83  39.28  5.87  3.31  1.31
#
#             Gd    Hf    Ho     La    Lu    Nb     Nd     Ni    Pr     Rb  \
# Location
# ANT001    5.64  4.46  1.23  22.60  0.48  9.39  22.72  36.27  5.69  73.92
# ANT002    5.21  4.09  1.14  21.23  0.45  8.29  21.08  41.11  5.26  65.61
#
#             Sm      Sr    Ta    Tb    Th    Tm     U       V      Y    Yb  \
# Location
# ANT001    5.17  143.45  0.75  0.96  9.55  0.52  1.61  273.91  31.01  3.32
# ANT002    4.79  156.94  0.66  0.89  9.01  0.49  1.57  264.56  29.01  3.09
#
#              Zn      Zr
# Location
# ANT001    98.64  159.99
# ANT002    96.72  145.91

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Matplotlib is a powerful plotting library. We will use it a lot to graph and show images.

# %%
import matplotlib.pyplot as plt

# %%
#Let's plot Mgo versus Zr
plt.figure(figsize=(6, 4))  # create a figure, you can adjust the numbers (10, 6) to your desired width and height

# actually plotting
plt.scatter(merged_assay_df['MgO'], # what's on the x-axis
         merged_assay_df['Zr'], # what's on the y-axis
         color="green", # colour of the line
         marker="o", # marker style
         alpha =0.5, #transparency
         s = 70,   #marker size   
         label="MgO vs Zr") # label for the legend

plt.legend(title="Legend") # place a legend
plt.title("MgO vs Zr in Antrim boreholes") # give a title to your plot
plt.xlabel("MgO (%)") # give label to your x axis
plt.ylabel("Zr (ppm)") # give label to your y axis
plt.savefig('Antrim_data/drillhole_images/Zr vs Mgo.jpg')
plt.show()
plt.close()

# %%
#Let's see how our standard (SY-4) has performed.
#First we'll prep that data for plotting.
sy4_expected = pd.read_excel('Antrim_data/drillhole_data/standard_sy4.xls')
sy4_measured = checks_standards_blanks[checks_standards_blanks['sampleid']=='SY-4']

shared_columns = sy4_expected.columns.intersection(sy4_measured.columns)
sy4_expected_measured = pd.concat([sy4_expected[shared_columns],sy4_measured[shared_columns]], ignore_index = True)

sy4_expected_measured.index=['expected', 'measured']
sy4_transposed = sy4_expected_measured.T
sy4_transposed
# Out:
#     expected  measured
# Ba     340.0   328.900
# Ce     122.0   122.770
# Co       2.8     2.000
# Cr      12.0    13.000
# Cu       7.0     3.000
# Dy      18.2    19.870
# Er      14.2    14.500
# Eu       2.0     1.950
# Gd      14.0    13.820
# Hf      10.6     1.130
# Ho       4.3     4.290
# La      58.0    54.390
# Lu       2.1     2.049
# Nb      13.0    14.600
# Nd      57.0    57.230
# Ni       9.0     8.000
# Pr      15.0    14.531
# Rb      55.0    53.490
# Sm      12.7    12.710
# Sr    1191.0  1170.000
# Ta       0.9     0.940
# Tb       2.6     2.669
# Th       1.4     1.410
# Tm       2.3     2.320
# U        0.8     0.730
# V        8.0     6.000
# Y      119.0   115.710
# Yb      14.8    14.960
# Zn      93.0    96.000
# Zr     517.0    66.200

# %% [markdown]
#  <font color="green"><b>TRY IT YOURSELF:</b> Using the scatterplot example as a guide, plot 'expected' versus 'measured' from the 'sy4_transposed' dataframe. <br>

# %%
#type your code here
plt.figure(figsize=(6, 4))  # create a figure, you can adjust the numbers (10, 6) to your desired width and height

# actually plotting
plt.scatter(sy4_transposed['expected'], # what's on the x-axis
         sy4_transposed['measured'], # what's on the y-axis
         color="green", # colour of the line
         marker="o", # marker style
         alpha =0.5, #transparency
         s = 70,   #marker size   
         label="SY4 expected vs measured") # label for the legend

plt.legend(title="Legend") # place a legend
plt.title("SY4 standard") # give a title to your plot
plt.xlabel("SY4 expected ") # give label to your x axis
plt.ylabel("SY4 measured") # give label to your y axis
plt.savefig('Antrim_data/drillhole_images/SY4_plot.jpg')
plt.show()
plt.close()

# %% [markdown]
# Seaborn is a popular plotting module that augments Matplotlib's functionality.

# %%
import seaborn as sns

plt.figure(figsize=(6, 4))
sns.scatterplot(data=merged_assay_df, x='MgO', y='Zr', hue='LOI', style='Location', s=100)
plt.title('Mgo vs Zr')
plt.xlabel('MgO (%)')
plt.ylabel('Zr (ppm)')
plt.show()
plt.close()

# %%
#Let's plot Mgo and Zr versus depth

fig, ax = plt.subplots(figsize=(10, 5))

# actually plotting
ax.plot(merged_assay_df['From'], # what's on the x-axis
         merged_assay_df['MgO'], # what's on the y-axis
         color="blue", # colour of the line
         ls="--", # linestyle
         label="Depth vs MgO") # label for the legend
ax.set_xlabel("Depth (m)") # give label to your x axis
ax.set_ylabel("MgO (%)") # give label to your y axis
ax.tick_params(labelrotation=45)


ax_zr = ax.twinx()
ax_zr.plot(merged_assay_df['From'], # what's on the x-axis
         merged_assay_df['Zr'], # what's on the y-axis
         color="red", # colour of the line
         ls="-", # linestyle
         label="MgO vs Zr") # label for the legend
ax_zr.set_xlabel("Depth (m)") # give label to your x axis
ax_zr.set_ylabel("Zr (ppm)") # give label to your y axis
ax_zr.tick_params(labelrotation=45)

# %%
fig, axes = plt.subplots(1,2,figsize=(8,10), sharey=True) # a figure with two plots in two different columns sharing the y-axis

axes[0].plot(merged_assay_df['MgO'],merged_assay_df['From'], color="blue",ls="--")
axes[1].plot(merged_assay_df['Fe2O3'],merged_assay_df['From'], color="red",ls=":")
axes[0].set_xlabel("MgO (%)") # give label to your x axis
axes[1].set_xlabel("Fe2O3 (%)")
axes[0].set_ylabel("Depth (m)")

plt.show()

# %% [markdown]
# ## Understanding errors

# %% [markdown]
# Let's run each of these cells and fix the errors that pop up.

# %%
if not os.path.isfile(os.path.join(folder_path,item):
# Out:
#   Cell In[80], line 1
#     if not os.path.isfile(os.path.join(folder_path,item):
#                                                         ^
# SyntaxError: invalid syntax

# %%
my_list = list(range(2,7))
print(f'my list contains {len(my_list)} items: {my_list}')
my_list_item = my_list[6]
# Out:
# my list contains 5 items: [2, 3, 4, 5, 6]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[81], line 3
#       1 my_list = list(range(2,7))
#       2 print(f'my list contains {len(my_list)} items: {my_list}')
# ----> 3 my_list_item = my_list[6]
#
# IndexError: list index out of range

# %%
grade_value = 10.5
print (grades_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 2
#       1 grade_value = 10.5
# ----> 2 print (grades_value)
#
# NameError: name 'grades_value' is not defined

# %%
for i in range(5):
print(i+5)
# Out:
#   Cell In[83], line 2
#     print(i+5)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
9/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 9/0
#
# ZeroDivisionError: division by zero

# %%
Antrim_drillhole_names = 'ant1'
Antrim_drillhole_names.append('ant2')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 2
#       1 Antrim_drillhole_names = 'ant1'
# ----> 2 Antrim_drillhole_names.append('ant2')
#
# AttributeError: 'str' object has no attribute 'append'

# %%
x = 9
y = 'eight'

print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 4
#       1 x = 9
#       2 y = 'eight'
# ----> 4 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(9 * 'eight')
# Out:
# eighteighteighteighteighteighteighteighteight

# %%
Antrim_collar_coordinates = {
    'ANT001': [572022, 7978167],
    'ANT002': [564818,7995173]
    }

print(Antrim_collar_coordinates['ANT003'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 6
#       1 Antrim_collar_coordinates = {
#       2     'ANT001': [572022, 7978167],
#       3     'ANT002': [564818,7995173]
#       4     }
# ----> 6 print(Antrim_collar_coordinates['ANT003'])
#
# KeyError: 'ANT003'

# %% [markdown]
# # Helpful (free) resources

# %% [markdown]
# - Online community forums e.g. Stack exchange (highly recommended - if  you have a question, it's probably been asked on stack exchange already)
# - Free learning websites e.g. Geeksforgeeks - great if you want a quick, clean example of  how to use a particular command.
# - Python modules  have documentation and tutorials online. There are important resources when you need to understand the specifics of any command you are running.
#
# ### A note on generative AI (ChatGPT, Gemini etc.)
# Generative AI can be extremely useful when coding. It can help you create data processing pipelines from plain-text prompts, help with debugging, or simply provide you the syntax for every-day commands. However, despite appearing intelligent, it is only a machine. Generative AI often makes mistakes and if you are not Python-literate, these can be hard to spot.  Just because the code works,  doesn't mean it's doing what you want!  However, if your company allows, it's a valuable tool to save  you time and help you learn. Remember not to put sensitive information into the model, as it may be used for training. Generative AI is powerful but we strongly recommend developing Python-literacy so you can guard against errors.
